# %% [markdown]
# # Formal Education, Experience, or Technical Specialization: Which Best Predicts Developer Salaries?
#
# A comparative analysis of education, experience, and technical specialization using the Stack Overflow Developer Survey.
#
# ## Research Question
#
# > **What is the relative importance of formal education, experience, and professional specialization in predicting developer salaries?**
#
# ## Objectives
#
# In this notebook we:
#
# - Understand the Stack Overflow 2025 Developer Survey.
# - Review the survey schema.
# - Select variables relevant to the research question.
# - Define the study population.
# - Perform univariate exploratory data analysis.

# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %%
# Opting out of output truncation for better data understanding

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None
pd.options.display.max_seq_items = None

# %% [markdown]
# ## Data Loading & Inspection
#
# The raw dataset can be found in `data/raw/results.csv`. The remote dataset can be found [here](https://media.githubusercontent.com/media/StackExchange/Survey/refs/heads/main/packages/archive/2025/results.csv).

# %%
url = "../data/raw/results.csv"

df = pd.read_csv(url, low_memory=False)

# Using low_memory=False to get more information on columns with mixed types

df.head()
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                              Employment  \
# 0                                              Employed
# 1                                              Employed
# 2  Independent contractor, freelancer, or self-employed
# ...

# %%
# Data Summary

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Columns: 172 entries, ResponseId to JobSat
# dtypes: float64(52), int64(1), str(119)
# memory usage: 64.6 MB

# %%
# Data Shape

df.shape # 49,191 rows, 172 columns
# Out:
# (49191, 172)

# %%
# Summary Statistics

df.describe()
# Out:
#          ResponseId       WorkExp     YearsCode  TechEndorse_1  TechEndorse_2  \
# count  49191.000000  42893.000000  43042.000000   35975.000000   35975.000000
# mean   24596.000000     13.367403     16.570861       7.867352       4.104211
# std    14200.362883     10.800117     11.787610       2.397432       2.275821
# min        1.000000      1.000000      1.000000       1.000000       1.000000
# 25%    12298.500000      5.000000      8.000000       7.000000       2.000000
# 50%    24596.000000     10.000000     14.000000       9.000000       4.000000
# 75%    36893.500000     20.000000     24.000000       9.000000       6.000000
# max    49191.000000    100.000000    100.000000      14.000000      14.000000
#
#        TechEndorse_3  TechEndorse_4  TechEndorse_5  TechEndorse_6  \
# count   35975.000000   35975.000000   35975.000000   35975.000000
# mean        4.110271       5.678193       4.119388       5.225990
# std         2.329536       2.398084       2.437945       2.801045
# ...

# %%
# Null Assessment

df.isna().sum().sort_values(ascending=False)
# Out:
# AIAgentObsWrite                             48927
# SOTagsWant Entry                            48761
# SOTagsHaveEntry                             48733
# AIModelsWantEntry                           48716
# AIAgentOrchWrite                            48713
# JobSatPoints_15_TEXT                        48527
# AIAgentKnowWrite                            48425
# AIModelsHaveEntry                           48415
# SO_Actions_15_TEXT                          48368
# AIAgentExtWrite                             48332
# CommPlatformWantEntr                        48007
# CommPlatformHaveEntr                        47715
# DatabaseWantEntry                           47658
# OfficeStackWantEntry                        47574
# TechOppose_15_TEXT                          47544
# TechEndorse_13_TEXT                         47182
# DevEnvWantEntry                             47079
# DatabaseHaveEntry                           47041
# OfficeStackHaveEntry                        46602
# ...

# %%
df["MainBranch"].value_counts() # Exclusion/Inclusion Criteria
# Out:
# MainBranch
# I am a developer by profession                                                                37467
# I am not primarily a developer, but I write code sometimes as part of my work/studies          4894
# I am learning to code                                                                          2585
# I code primarily as a hobby                                                                    1924
# I used to be a developer by profession, but no longer am                                       1325
# I work with developers or my work supports developers but am not a developer by profession      996
# Name: count, dtype: int64

# %% [markdown]
# ## Schema Exploration
#
# The schema for this dataset can be found in `schema/schema.csv`.

# %%
# Reviewing the survey schema and column definitions

schema_url = "../schema/schema.csv"

schema = pd.read_csv(schema_url)

schema[["qname", "question"]]
# Out:
#                     qname  \
# 0           TechEndorse_1
# 1           TechEndorse_2
# 2           TechEndorse_3
# 3           TechEndorse_4
# 4           TechEndorse_5
# 5           TechEndorse_6
# 6           TechEndorse_7
# 7           TechEndorse_8
# 8           TechEndorse_9
# 9          TechEndorse_13
# 10    TechEndorse_13_TEXT
# 11           TechOppose_1
# 12           TechOppose_2
# 13           TechOppose_3
# 14           TechOppose_5
# 15           TechOppose_7
# 16           TechOppose_9
# 17          TechOppose_11
# 18          TechOppose_13
# 19          TechOppose_16
# 20          TechOppose_15
# 21     TechOppose_15_TEXT
# 22         JobSatPoints_1
# 23         JobSatPoints_2
# 24        JobSatPoints_16
# 25         JobSatPoints_3
# 26         JobSatPoints_4
# 27         JobSatPoints_5
# 28         JobSatPoints_6
# 29         JobSatPoints_7
# 30         JobSatPoints_8
# 31         JobSatPoints_9
# 32        JobSatPoints_10
# 33        JobSatPoints_11
# ...

# %% [markdown]
# ### Key Takeaways
#
# - The dataset contains 172 variables.
# - Variables span demographics, education, employment, technology use, compensation, and developer preferences.
# - A schema file is available and will be used to guide feature selection.
# - Subsequent work will focus on preparing the dataset for analysis.
